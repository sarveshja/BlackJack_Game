# %%
import random
def game():
    vals = [11,2,3,4,5,6,7,8,9,10,10,10,10]
    user = []
    computer = []
    user1 = user.append(random.choice(vals))
    user2 = user.append(random.choice(vals))
    print("Your cards:",user)
    computer1 = computer.append(random.choice(vals))
    print("Computer cards:",computer)
    ch = input("Type 'y' to get another card ot Type 'n' to pass:")
    if(ch=='y'):
        user3 = user.append(random.choice(vals))
    user_sum = sum(user)
    computer2 = computer.append(random.choice(vals))
    computer_sum = sum(computer)
    if(computer_sum<17):
        computer3 = computer.append(random.choice(vals))
        computer_sum = sum(computer)
    print("Your final cards:",user)
    print("Your final score:",user_sum)
    print("Computer's final cards:",computer)
    print("Computer's final score:",computer_sum)
    if(user_sum>21):
        print("You went over  21. YOU LOST")
    elif(user_sum==computer_sum):
        print("Draw")
    elif(user_sum<computer_sum):
        print("You lost")
    elif(user_sum>computer_sum):
        print("YOU WON")
    choice = input("Do you want to play a game of blackjack. Type 'y' or 'n':")
    if(choice=='y'):
        game()
    

game()
# Out:
# Your cards: [5, 5]
# Computer cards: [4]
# Type 'y' to get another card ot Type 'n' to pass:y
# Your final cards: [5, 5, 10]
# Your final score: 20
# Computer's final cards: [4, 10, 7]
# Computer's final score: 21
# You lost
# Do you want to play a game of blackjack. Type 'y' or 'n':y
# Your cards: [11, 8]
# Computer cards: [11]
# Type 'y' to get another card ot Type 'n' to pass:n
# Your final cards: [11, 8]
# Your final score: 19
# Computer's final cards: [11, 7]
# Computer's final score: 18
# YOU WON
# Do you want to play a game of blackjack. Type 'y' or 'n':n

# %%
import random
def game():
    vals = [11,2,3,4,5,6,7,8,9,10,10,10,10]
    user = []
    computer = []
    user1 = user.append(random.choice(vals))
    user2 = user.append(random.choice(vals))
    print("Your cards:",user)
    computer1 = computer.append(random.choice(vals))
    print("Computer cards:",computer)
    ch = input("Type 'y' to get another card ot Type 'n' to pass:")
    if(ch=='y'):
        user3 = random.choice(vals)
        if(user3==11 and sum(user)+user3>21):
            user.append(1)
        else:
            user.append(user3)
    user_sum = sum(user)
    computer2 = computer.append(random.choice(vals))
    computer_sum = sum(computer)
    if(computer_sum<17):
        computer3 = random.choice(vals)
        if(computer3==11 and sum(computer)+computer3>21):
            computer.append(1)
        else:
            computer.append(computer3)
    computer_sum = sum(computer)
    print("Your final cards:",user)
    print("Your final score:",user_sum)
    print("Computer's final cards:",computer)
    print("Computer's final score:",computer_sum)
    if(user_sum>21):
        print("You went over  21. YOU LOST")
    elif(user_sum==computer_sum):
        print("Draw")
    elif(user_sum<computer_sum):
        print("You lost")
    elif(user_sum>computer_sum):
        print("YOU WON")
    choice = input("Do you want to play a game of blackjack. Type 'y' or 'n':")
    if(choice=='y'):
        game()
    

game()
# Out:
# Your cards: [9, 10]
# Computer cards: [2]
# Type 'y' to get another card ot Type 'n' to pass:n
# Your final cards: [9, 10]
# Your final score: 19
# Computer's final cards: [2, 10, 4]
# Computer's final score: 16
# YOU WON
# Do you want to play a game of blackjack. Type 'y' or 'n':y
# Your cards: [6, 3]
# Computer cards: [10]
# Type 'y' to get another card ot Type 'n' to pass:y
# Your final cards: [6, 3, 6]
# Your final score: 15
# Computer's final cards: [10, 11]
# Computer's final score: 21
# You lost
# Do you want to play a game of blackjack. Type 'y' or 'n':y
# Your cards: [4, 6]
# Computer cards: [10]
# Type 'y' to get another card ot Type 'n' to pass:y
# Your final cards: [4, 6, 11]
# Your final score: 21
# Computer's final cards: [10, 3, 5]
# Computer's final score: 18
# YOU WON
# Do you want to play a game of blackjack. Type 'y' or 'n':y
# Your cards: [10, 2]
# Computer cards: [5]
# Type 'y' to get another card ot Type 'n' to pass:y
# Your final cards: [10, 2, 1]
# ...

# %%
import random
def game():
    vals = [11,2,3,4,5,6,7,8,9,10,10,10,10]
    user = []
    computer = []
    user1 = user.append(random.choice(vals))
    user2 = user.append(random.choice(vals))
    print("Your cards:",user)
    computer1 = computer.append(random.choice(vals))
    print("Computer cards:",computer)
    
    while(input("Type 'y' to get another card ot Type 'n' to pass:")=='y'):
        user3 = random.choice(vals)
        if(user3==11 and sum(user)+user3>21):
            user.append(1)
            user_sum = sum(user)
        else:
            user.append(user3)
            user_sum = sum(user)
        print("Your final cards:",user)
        print("Your final score:",user_sum) 
    computer2 = computer.append(random.choice(vals))
    computer_sum = sum(computer)
    while(computer_sum<17):
        computer3 = random.choice(vals)
        if(computer3==11 and sum(computer)+computer3>21):
            computer.append(1)
        else:
            computer.append(computer3)
    computer_sum = sum(computer)
    
    print("Computer's final cards:",computer)
    print("Computer's final score:",computer_sum)
    if(user_sum>21):
        print("You went over  21. YOU LOST")
    elif(user_sum==computer_sum):
        print("Draw")
    elif(user_sum<computer_sum):
        print("You lost")
    elif(user_sum>computer_sum):
        print("YOU WON")
    choice = input("Do you want to play a game of blackjack. Type 'y' or 'n':")
    if(choice=='y'):
        game()
    

game()
# Out:
# Your cards: [8, 7]
# Computer cards: [6]
